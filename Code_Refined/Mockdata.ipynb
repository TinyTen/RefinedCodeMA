# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('../Data/nutrition.csv', index_col=0)
data.set_index('name', inplace=True)

# %%
data[~data.isnull().any(axis=1)].loc['Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, eye of round roast, round'].head(60)
# Out:
# serving_size              100 g
# calories                    121
# total_fat                    3g
# saturated_fat              1.1g
# cholesterol                60mg
# sodium                 53.00 mg
# choline                 64.2 mg
# folate                 4.00 mcg
# folic_acid             0.00 mcg
# niacin                 6.720 mg
# pantothenic_acid       0.355 mg
# riboflavin             0.184 mg
# thiamin                0.063 mg
# vitamin_a               4.00 IU
# vitamin_a_rae          1.00 mcg
# carotene_alpha         0.00 mcg
# carotene_beta          0.00 mcg
# cryptoxanthin_beta     0.00 mcg
# lutein_zeaxanthin      0.00 mcg
# lucopene                      0
# vitamin_b12            1.84 mcg
# vitamin_b6             0.644 mg
# vitamin_c                0.0 mg
# vitamin_d               1.00 IU
# vitamin_e               0.24 mg
# tocopherol_alpha        0.24 mg
# vitamin_k               1.5 mcg
# calcium                13.00 mg
# copper                 0.042 mg
# irom                    1.45 mg
# magnesium              12.00 mg
# manganese              0.001 mg
# phosphorous           222.00 mg
# potassium             319.00 mg
# selenium               22.6 mcg
# zink                    3.42 mg
# protein                 23.37 g
# alanine                 1.525 g
# arginine                1.714 g
# aspartic_acid           2.468 g
# cystine                 0.256 g
# glutamic_acid           4.167 g
# glycine                 1.101 g
# histidine               0.948 g
# hydroxyproline          0.118 g
# isoleucine              1.192 g
# leucine                 2.198 g
# lysine                  2.457 g
# methionine              0.679 g
# phenylalanine           1.018 g
# proline                 1.073 g
# serine                  1.037 g
# threonine               1.201 g
# tryptophan              0.287 g
# tyrosine                0.954 g
# valine                  1.259 g
# carbohydrate             0.00 g
# fiber                     0.0 g
# sugars                   0.00 g
# fructose                      0
# Name: Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, eye of round roast, round, dtype: object

# %%
units = data.loc['Sherbet, orange'].str.extract(r"([a-z]+)")

# %%
combine_columns = []
for i in range(len(units)):
    combined = str(data.columns[i]) + ' [' + str(units[0][i]) + ']'
    combine_columns.append(combined)
combine_columns
# Out:
# ['serving_size [g]',
#  'calories [nan]',
#  'total_fat [g]',
#  'saturated_fat [g]',
#  'cholesterol [mg]',
#  'sodium [mg]',
#  'choline [mg]',
#  'folate [mcg]',
#  'folic_acid [mcg]',
#  'niacin [mg]',
#  'pantothenic_acid [mg]',
#  'riboflavin [mg]',
#  'thiamin [mg]',
#  'vitamin_a [nan]',
#  'vitamin_a_rae [mcg]',
#  'carotene_alpha [mcg]',
#  'carotene_beta [mcg]',
#  'cryptoxanthin_beta [mcg]',
#  'lutein_zeaxanthin [mcg]',
#  'lucopene [nan]',
#  'vitamin_b12 [mcg]',
#  'vitamin_b6 [mg]',
#  'vitamin_c [mg]',
#  'vitamin_d [nan]',
#  'vitamin_e [mg]',
#  'tocopherol_alpha [mg]',
#  'vitamin_k [mcg]',
#  'calcium [mg]',
#  'copper [mg]',
#  'irom [mg]',
#  'magnesium [mg]',
#  'manganese [mg]',
#  'phosphorous [mg]',
#  'potassium [mg]',
#  'selenium [mcg]',
#  'zink [mg]',
#  'protein [g]',
#  'alanine [nan]',
#  'arginine [nan]',
#  'aspartic_acid [nan]',
#  'cystine [nan]',
#  'glutamic_acid [nan]',
#  'glycine [nan]',
#  'histidine [nan]',
#  'hydroxyproline [nan]',
#  'isoleucine [nan]',
#  'leucine [nan]',
#  'lysine [nan]',
#  'methionine [nan]',
#  'phenylalanine [nan]',
#  'proline [nan]',
#  'serine [nan]',
#  'threonine [nan]',
#  'tryptophan [nan]',
#  'tyrosine [nan]',
#  'valine [nan]',
#  'carbohydrate [g]',
#  'fiber [g]',
#  'sugars [g]',
#  'fructose [nan]',
#  'galactose [nan]',
#  'glucose [nan]',
#  'lactose [nan]',
#  'maltose [nan]',
#  'sucrose [nan]',
#  'fat [g]',
#  'saturated_fatty_acids [g]',
#  'monounsaturated_fatty_acids [g]',
#  'polyunsaturated_fatty_acids [g]',
#  'fatty_acids_total_trans [mg]',
#  'alcohol [g]',
#  'ash [g]',
#  'caffeine [mg]',
#  'theobromine [mg]',
#  'water [g]']

# %%
data.columns
# Out:
# Index(['serving_size', 'calories', 'total_fat', 'saturated_fat', 'cholesterol',
#        'sodium', 'choline', 'folate', 'folic_acid', 'niacin',
#        'pantothenic_acid', 'riboflavin', 'thiamin', 'vitamin_a',
#        'vitamin_a_rae', 'carotene_alpha', 'carotene_beta',
#        'cryptoxanthin_beta', 'lutein_zeaxanthin', 'lucopene', 'vitamin_b12',
#        'vitamin_b6', 'vitamin_c', 'vitamin_d', 'vitamin_e', 'tocopherol_alpha',
#        'vitamin_k', 'calcium', 'copper', 'irom', 'magnesium', 'manganese',
#        'phosphorous', 'potassium', 'selenium', 'zink', 'protein', 'alanine',
#        'arginine', 'aspartic_acid', 'cystine', 'glutamic_acid', 'glycine',
#        'histidine', 'hydroxyproline', 'isoleucine', 'leucine', 'lysine',
#        'methionine', 'phenylalanine', 'proline', 'serine', 'threonine',
#        'tryptophan', 'tyrosine', 'valine', 'carbohydrate', 'fiber', 'sugars',
#        'fructose', 'galactose', 'glucose', 'lactose', 'maltose', 'sucrose',
#        'fat', 'saturated_fatty_acids', 'monounsaturated_fatty_acids',
#        'polyunsaturated_fatty_acids', 'fatty_acids_total_trans', 'alcohol',
#        'ash', 'caffeine', 'theobromine', 'water'],
#       dtype='object')

# %%
data['polyunsaturated_fatty_acids'] = data['polyunsaturated_fatty_acids'].str.extract('([-+]?\d*\.?\d+)')

# %%
data['polyunsaturated_fatty_acids']
# Out:
# name
# Cornstarch                                                                                             0.025
# Nuts, pecans                                                                                          21.614
# Eggplant, raw                                                                                          0.076
# Teff, uncooked                                                                                         1.071
# Sherbet, orange                                                                                        0.080
#                                                                                                        ...
# Beef, raw, all grades, trimmed to 0" fat, separable lean and fat, boneless, top round roast, round     0.244
# Lamb, cooked, separable lean only, composite of trimmed retail cuts, frozen, imported, New Zealand     0.520
# Lamb, raw, separable lean and fat, composite of trimmed retail cuts, frozen, imported, New Zealand     0.980
# Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, eye of round roast, round     0.233
# Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, eye of round steak, round     0.233
# Name: polyunsaturated_fatty_acids, Length: 8789, dtype: object

# %%
data.fillna('NaN', inplace=True)

# %%
data['lucopene'] = data['lucopene'].astype(str)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8789 entries, Cornstarch to Beef, raw, all grades, trimmed to 0" fat, separable lean only, boneless, eye of round steak, round
# Data columns (total 75 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   serving_size                 8789 non-null   object
#  1   calories                     8789 non-null   int64
#  2   total_fat                    8789 non-null   object
#  3   saturated_fat                8789 non-null   object
#  4   cholesterol                  8789 non-null   object
#  5   sodium                       8789 non-null   object
#  6   choline                      8789 non-null   object
#  7   folate                       8789 non-null   object
#  8   folic_acid                   8789 non-null   object
#  9   niacin                       8789 non-null   object
#  10  pantothenic_acid             8789 non-null   object
#  11  riboflavin                   8789 non-null   object
#  12  thiamin                      8789 non-null   object
#  13  vitamin_a                    8789 non-null   object
#  14  vitamin_a_rae                8789 non-null   object
#  15  carotene_alpha               8789 non-null   object
#  16  carotene_beta                8789 non-null   object
#  17  cryptoxanthin_beta           8789 non-null   object
#  18  lutein_zeaxanthin            8789 non-null   object
#  19  lucopene                     8789 non-null   object
#  20  vitamin_b12                  8789 non-null   object
#  21  vitamin_b6                   8789 non-null   object
#  22  vitamin_c                    8789 non-null   object
#  23  vitamin_d                    8789 non-null   object
#  24  vitamin_e                    8789 non-null   object
#  25  tocopherol_alpha             8789 non-null   object
#  26  vitamin_k                    8789 non-null   object
#  27  calcium                      8789 non-null   object
#  28  copper                       8789 non-null   object
#  29  irom                         8789 non-null   object
#  30  magnesium                    8789 non-null   object
#  31  manganese                    8789 non-null   object
#  32  phosphorous                  8789 non-null   object
#  33  potassium                    8789 non-null   object
#  34  selenium                     8789 non-null   object
#  35  zink                         8789 non-null   object
#  36  protein                      8789 non-null   object
#  37  alanine                      8789 non-null   object
#  38  arginine                     8789 non-null   object
#  39  aspartic_acid                8789 non-null   object
#  40  cystine                      8789 non-null   object
#  41  glutamic_acid                8789 non-null   object
#  42  glycine                      8789 non-null   object
#  43  histidine                    8789 non-null   object
#  44  hydroxyproline               8789 non-null   object
#  45  isoleucine                   8789 non-null   object
#  46  leucine                      8789 non-null   object
#  47  lysine                       8789 non-null   object
#  48  methionine                   8789 non-null   object
#  49  phenylalanine                8789 non-null   object
#  50  proline                      8789 non-null   object
#  51  serine                       8789 non-null   object
#  52  threonine                    8789 non-null   object
#  53  tryptophan                   8789 non-null   object
#  54  tyrosine                     8789 non-null   object
#  55  valine                       8789 non-null   object
#  56  carbohydrate                 8789 non-null   object
#  57  fiber                        8789 non-null   object
#  58  sugars                       8789 non-null   object
#  59  fructose                     8789 non-null   object
#  60  galactose                    8789 non-null   object
#  61  glucose                      8789 non-null   object
#  62  lactose                      8789 non-null   object
#  63  maltose                      8789 non-null   object
#  64  sucrose                      8789 non-null   object
#  65  fat                          8789 non-null   object
#  66  saturated_fatty_acids        8789 non-null   object
#  67  monounsaturated_fatty_acids  8789 non-null   object
#  68  polyunsaturated_fatty_acids  8789 non-null   object
#  69  fatty_acids_total_trans      8789 non-null   object
#  70  alcohol                      8789 non-null   object
#  71  ash                          8789 non-null   object
#  72  caffeine                     8789 non-null   object
#  73  theobromine                  8789 non-null   object
#  74  water                        8789 non-null   object
# dtypes: int64(1), object(74)
# memory usage: 5.3+ MB

# %%
mixed = ['serving_size','total_fat', 'saturated_fat',
       'cholesterol', 'sodium', 'choline', 'folate', 'folic_acid', 'niacin',
       'pantothenic_acid', 'riboflavin', 'thiamin', 'vitamin_a',
       'vitamin_a_rae', 'carotene_alpha', 'carotene_beta',
       'cryptoxanthin_beta', 'lutein_zeaxanthin', 'lucopene', 'vitamin_b12',
       'vitamin_b6', 'vitamin_c', 'vitamin_d', 'vitamin_e', 'tocopherol_alpha',
       'vitamin_k', 'calcium', 'copper', 'irom', 'magnesium', 'manganese',
       'phosphorous', 'potassium', 'selenium', 'zink', 'protein', 'alanine',
       'arginine', 'aspartic_acid', 'cystine', 'glutamic_acid', 'glycine',
       'histidine', 'hydroxyproline', 'isoleucine', 'leucine', 'lysine',
       'methionine', 'phenylalanine', 'proline', 'serine', 'threonine',
       'tryptophan', 'tyrosine', 'valine', 'carbohydrate', 'fiber', 'sugars',
       'fructose', 'galactose', 'glucose', 'lactose', 'maltose', 'sucrose',
       'fat', 'saturated_fatty_acids', 'monounsaturated_fatty_acids',
       'polyunsaturated_fatty_acids', 'fatty_acids_total_trans', 'alcohol',
       'ash', 'caffeine', 'theobromine', 'water']
for column in mixed:
#     if type(data[column][0]) ==str:
        data[column] = data[column].str.extract('([-+]?\d*\.?\d+)')
        print(column)
# Out:
# serving_size
# total_fat
# saturated_fat
# cholesterol
# sodium
# choline
# folate
# folic_acid
# niacin
# pantothenic_acid
# riboflavin
# thiamin
# vitamin_a
# vitamin_a_rae
# carotene_alpha
# carotene_beta
# cryptoxanthin_beta
# lutein_zeaxanthin
# lucopene
# vitamin_b12
# vitamin_b6
# vitamin_c
# vitamin_d
# vitamin_e
# tocopherol_alpha
# vitamin_k
# calcium
# copper
# irom
# magnesium
# manganese
# phosphorous
# potassium
# selenium
# zink
# protein
# alanine
# arginine
# aspartic_acid
# cystine
# glutamic_acid
# glycine
# histidine
# hydroxyproline
# isoleucine
# leucine
# lysine
# methionine
# phenylalanine
# proline
# serine
# threonine
# tryptophan
# tyrosine
# valine
# carbohydrate
# fiber
# sugars
# fructose
# galactose
# glucose
# lactose
# maltose
# sucrose
# fat
# saturated_fatty_acids
# monounsaturated_fatty_acids
# polyunsaturated_fatty_acids
# fatty_acids_total_trans
# alcohol
# ash
# caffeine
# theobromine
# water

# %%
data
# Out:
#                                                    serving_size  calories  \
# name
# Cornstarch                                                  100       381
# Nuts, pecans                                                100       691
# Eggplant, raw                                               100        25
# Teff, uncooked                                              100       367
# Sherbet, orange                                             100       144
# ...                                                         ...       ...
# Beef, raw, all grades, trimmed to 0" fat, separ...          100       125
# Lamb, cooked, separable lean only, composite of...          100       206
# Lamb, raw, separable lean and fat, composite of...          100       277
# Beef, raw, all grades, trimmed to 0" fat, separ...          100       121
# Beef, raw, all grades, trimmed to 0" fat, separ...          100       121
#
#                                                    total_fat saturated_fat  \
# name
# Cornstarch                                               0.1           NaN
# Nuts, pecans                                              72           6.2
# Eggplant, raw                                            0.2           NaN
# Teff, uncooked                                           2.4           0.4
# Sherbet, orange                                            2           1.2
# ...                                                      ...           ...
# Beef, raw, all grades, trimmed to 0" fat, separ...       3.5           1.4
# Lamb, cooked, separable lean only, composite of...       8.9           3.9
# Lamb, raw, separable lean and fat, composite of...        23            12
# Beef, raw, all grades, trimmed to 0" fat, separ...         3           1.1
# Beef, raw, all grades, trimmed to 0" fat, separ...         3           1.1
#
#                                                    cholesterol sodium choline  \
# name
# Cornstarch                                                   0   9.00     0.4
# Nuts, pecans                                                 0   0.00    40.5
# Eggplant, raw                                                0   2.00     6.9
# Teff, uncooked                                               0  12.00    13.1
# Sherbet, orange                                              1  46.00     7.7
# ...                                                        ...    ...     ...
# Beef, raw, all grades, trimmed to 0" fat, separ...          62  54.00    64.5
# Lamb, cooked, separable lean only, composite of...         109  50.00       0
# Lamb, raw, separable lean and fat, composite of...          78  39.00       0
# Beef, raw, all grades, trimmed to 0" fat, separ...          60  53.00    64.2
# Beef, raw, all grades, trimmed to 0" fat, separ...          60  53.00    64.2
#
#                                                    folate folic_acid niacin  \
# name
# Cornstarch                                           0.00       0.00  0.000
# Nuts, pecans                                        22.00       0.00  1.167
# Eggplant, raw                                       22.00       0.00  0.649
# Teff, uncooked                                          0          0  3.363
# Sherbet, orange                                      4.00       0.00  0.063
# ...                                                   ...        ...    ...
# Beef, raw, all grades, trimmed to 0" fat, separ...   4.00       0.00  6.422
# Lamb, cooked, separable lean only, composite of...   0.00       0.00  7.680
# Lamb, raw, separable lean and fat, composite of...   1.00       0.00  6.550
# Beef, raw, all grades, trimmed to 0" fat, separ...   4.00       0.00  6.720
# Beef, raw, all grades, trimmed to 0" fat, separ...   4.00       0.00  6.720
#
#                                                     ...    fat  \
# name                                                ...
# Cornstarch                                          ...   0.05
# Nuts, pecans                                        ...  71.97
# Eggplant, raw                                       ...   0.18
# Teff, uncooked                                      ...   2.38
# Sherbet, orange                                     ...   2.00
# ...                                                 ...    ...
# Beef, raw, all grades, trimmed to 0" fat, separ...  ...   3.50
# Lamb, cooked, separable lean only, composite of...  ...   8.86
# Lamb, raw, separable lean and fat, composite of...  ...  22.74
# Beef, raw, all grades, trimmed to 0" fat, separ...  ...   3.04
# Beef, raw, all grades, trimmed to 0" fat, separ...  ...   3.04
#
#                                                    saturated_fatty_acids  \
# name
# Cornstarch                                                         0.009
# Nuts, pecans                                                       6.180
# Eggplant, raw                                                      0.034
# Teff, uncooked                                                     0.449
# Sherbet, orange                                                    1.160
# ...                                                                  ...
# Beef, raw, all grades, trimmed to 0" fat, separ...                 1.353
# Lamb, cooked, separable lean only, composite of...                 3.860
# Lamb, raw, separable lean and fat, composite of...                11.570
# Beef, raw, all grades, trimmed to 0" fat, separ...                 1.086
# Beef, raw, all grades, trimmed to 0" fat, separ...                 1.086
#
#                                                    monounsaturated_fatty_acids  \
# name
# Cornstarch                                                               0.016
# Nuts, pecans                                                            40.801
# Eggplant, raw                                                            0.016
# Teff, uncooked                                                           0.589
# Sherbet, orange                                                          0.530
# ...                                                                        ...
# Beef, raw, all grades, trimmed to 0" fat, separ...                       1.554
# Lamb, cooked, separable lean only, composite of...                       3.480
# Lamb, raw, separable lean and fat, composite of...                       8.720
# Beef, raw, all grades, trimmed to 0" fat, separ...                       1.266
# Beef, raw, all grades, trimmed to 0" fat, separ...                       1.266
#
#                                                    polyunsaturated_fatty_acids  \
# name
# Cornstarch                                                               0.025
# Nuts, pecans                                                            21.614
# Eggplant, raw                                                            0.076
# Teff, uncooked                                                           1.071
# Sherbet, orange                                                          0.080
# ...                                                                        ...
# Beef, raw, all grades, trimmed to 0" fat, separ...                       0.244
# Lamb, cooked, separable lean only, composite of...                       0.520
# Lamb, raw, separable lean and fat, composite of...                       0.980
# Beef, raw, all grades, trimmed to 0" fat, separ...                       0.233
# Beef, raw, all grades, trimmed to 0" fat, separ...                       0.233
#
#                                                    fatty_acids_total_trans  \
# name
# Cornstarch                                                            0.00
# Nuts, pecans                                                          0.00
# Eggplant, raw                                                         0.00
# Teff, uncooked                                                           0
# Sherbet, orange                                                       1.00
# ...                                                                    ...
# Beef, raw, all grades, trimmed to 0" fat, separ...                   62.00
# Lamb, cooked, separable lean only, composite of...                  109.00
# Lamb, raw, separable lean and fat, composite of...                   78.00
# Beef, raw, all grades, trimmed to 0" fat, separ...                   60.00
# Beef, raw, all grades, trimmed to 0" fat, separ...                   60.00
#
#                                                    alcohol   ash caffeine  \
# name
# Cornstarch                                             0.0  0.09     0.00
# Nuts, pecans                                           0.0  1.49     0.00
# Eggplant, raw                                          0.0  0.66     0.00
# Teff, uncooked                                           0  2.37        0
# Sherbet, orange                                        0.0  0.40     0.00
# ...                                                    ...   ...      ...
# Beef, raw, all grades, trimmed to 0" fat, separ...     0.0  1.11     0.00
# Lamb, cooked, separable lean only, composite of...       0  1.60        0
# Lamb, raw, separable lean and fat, composite of...       0  0.92        0
# Beef, raw, all grades, trimmed to 0" fat, separ...     0.0  1.10     0.00
# Beef, raw, all grades, trimmed to 0" fat, separ...     0.0  1.10     0.00
#
#                                                    theobromine  water
# name
# Cornstarch                                                0.00   8.32
# Nuts, pecans                                              0.00   3.52
# Eggplant, raw                                             0.00  92.30
# Teff, uncooked                                               0   8.82
# Sherbet, orange                                           0.00  66.10
# ...                                                        ...    ...
# Beef, raw, all grades, trimmed to 0" fat, separ...        0.00  72.51
# Lamb, cooked, separable lean only, composite of...           0  59.95
# Lamb, raw, separable lean and fat, composite of...           0  59.80
# Beef, raw, all grades, trimmed to 0" fat, separ...        0.00  73.43
# Beef, raw, all grades, trimmed to 0" fat, separ...        0.00  73.43
#
# [8789 rows x 75 columns]

# %%
combine_columns
# Out:
# ['serving_size [g]',
#  'calories [nan]',
#  'total_fat [g]',
#  'saturated_fat [g]',
#  'cholesterol [mg]',
#  'sodium [mg]',
#  'choline [mg]',
#  'folate [mcg]',
#  'folic_acid [mcg]',
#  'niacin [mg]',
#  'pantothenic_acid [mg]',
#  'riboflavin [mg]',
#  'thiamin [mg]',
#  'vitamin_a [nan]',
#  'vitamin_a_rae [mcg]',
#  'carotene_alpha [mcg]',
#  'carotene_beta [mcg]',
#  'cryptoxanthin_beta [mcg]',
#  'lutein_zeaxanthin [mcg]',
#  'lucopene [nan]',
#  'vitamin_b12 [mcg]',
#  'vitamin_b6 [mg]',
#  'vitamin_c [mg]',
#  'vitamin_d [nan]',
#  'vitamin_e [mg]',
#  'tocopherol_alpha [mg]',
#  'vitamin_k [mcg]',
#  'calcium [mg]',
#  'copper [mg]',
#  'irom [mg]',
#  'magnesium [mg]',
#  'manganese [mg]',
#  'phosphorous [mg]',
#  'potassium [mg]',
#  'selenium [mcg]',
#  'zink [mg]',
#  'protein [g]',
#  'alanine [nan]',
#  'arginine [nan]',
#  'aspartic_acid [nan]',
#  'cystine [nan]',
#  'glutamic_acid [nan]',
#  'glycine [nan]',
#  'histidine [nan]',
#  'hydroxyproline [nan]',
#  'isoleucine [nan]',
#  'leucine [nan]',
#  'lysine [nan]',
#  'methionine [nan]',
#  'phenylalanine [nan]',
#  'proline [nan]',
#  'serine [nan]',
#  'threonine [nan]',
#  'tryptophan [nan]',
#  'tyrosine [nan]',
#  'valine [nan]',
#  'carbohydrate [g]',
#  'fiber [g]',
#  'sugars [g]',
#  'fructose [nan]',
#  'galactose [nan]',
#  'glucose [nan]',
#  'lactose [nan]',
#  'maltose [nan]',
#  'sucrose [nan]',
#  'fat [g]',
#  'saturated_fatty_acids [g]',
#  'monounsaturated_fatty_acids [g]',
#  'polyunsaturated_fatty_acids [g]',
#  'fatty_acids_total_trans [mg]',
#  'alcohol [g]',
#  'ash [g]',
#  'caffeine [mg]',
#  'theobromine [mg]',
#  'water [g]']

# %%
data.columns = combine_columns

# %%
# data.to_excel('Nutrition.xlsx')

# %%
# ! pip install googletrans

# %%
data.reset_index(inplace=True)

# %%
data.name
# Out:
# 0                                              Cornstarch
# 1                                            Nuts, pecans
# 2                                           Eggplant, raw
# 3                                          Teff, uncooked
# 4                                         Sherbet, orange
#                               ...
# 8784    Beef, raw, all grades, trimmed to 0" fat, sepa...
# 8785    Lamb, cooked, separable lean only, composite o...
# 8786    Lamb, raw, separable lean and fat, composite o...
# 8787    Beef, raw, all grades, trimmed to 0" fat, sepa...
# 8788    Beef, raw, all grades, trimmed to 0" fat, sepa...
# Name: name, Length: 8789, dtype: object

# %%
# !pip uninstall googletrans
# !pip install googletrans==4.0.0rc1

# %%
from googletrans import Translator
translator = Translator()
ar = translator.translate('مرحبا').
print(ar)
# Out:
# Welcome

# %%
from googletrans import Translator

translator = Translator()
data1 = data.name[:20].apply(lambda x: translator.translate(x, dest='de').text)
print(data1)
# Out:
# 0                            Maisstärke
# 1                     Nüsse, Pekannüsse
# 2                        Aubergine, roh
# 3                       Teff, ungekocht
# 4                       Sherbet, Orange
# 5                       Blumenkohl, roh
# 6                      Taroblätter, roh
# 7                   Lamm, roh, gemahlen
# 8                       Käse, Camembert
# 9                   Vegetarische Filets
# 10                Tempo, Picante -Sauce
# 11             Goji -Beeren, getrocknet
# 12                 Mango -Nektar, Dosen
# 13                  Cracks, Reis -Toast
# 14                  Huhn, gekocht, Füße
# 15            Wachtel, roh, nur Fleisch
# 16    Kuchen, Zitrone, gebratene Kuchen
# 17               Paprika, roh, Jalapeno
# 18        Geflügelte Bohnenknollen, roh
# 19              Salami, Türkei, gekocht
# Name: name, dtype: object
